# %%
class BFS:
    def __init__(self, graph):
        self.graph = graph
        self.visited = []

    def search(self, start, goal):
        self.visited = []
        level = [start]

        while level:
            next_level = []
            for node in level:
                if node not in self.visited:
                    self.visited.append(node)

                    if node == goal:
                        print("Found")
                        return

                    next_level.extend(self.graph[node])
            level = next_level

        print("Not Found")

    def get_visited(self):
        return self.visited


graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F"],
    "D": [],
    "E": [],
    "F": ["G"],
    "G": []
}

bfs = BFS(graph)
bfs.search("A", "G")
print("Visited order:", bfs.get_visited())
# Out:
# Found
# Visited order: ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
def bfs(graph, start_node, target_node):
    visited_nodes = []
    queue = [start_node]

    while queue:
        current_node = queue.pop(0)

        if current_node not in visited_nodes:
            visited_nodes.append(current_node)

            if current_node == target_node:
                print("Target Found")
                return visited_nodes

            queue.extend(graph[current_node])

    print("Target Not Found")
    return visited_nodes


graph_data = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F", "H"],  
    "D": [],
    "E": [],
    "F": ["G"],
    "G": ["I"],      
    "H": [],
    "I": []
}

result = bfs(graph_data, "A", "I")
print("Traversal sequence:", result)
# Out:
# Target Found
# Traversal sequence: ['A', 'B', 'C', 'D', 'E', 'F', 'H', 'G', 'I']
